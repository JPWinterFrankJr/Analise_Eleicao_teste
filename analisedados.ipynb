# %%
# Libs para Modelagem e Matrizez
import numpy as np
import pandas as pd

# %%
#indicar o caminho do arquivo(onde o arquivo está localizado na maquina)
path = r"D:\eleitorado\perfil_eleitorado_2020\perfil_eleitorado_2020.csv"

# %%
base_dados = pd.read_csv(path, sep=';',encoding='ISO-8859-1')

# %%
base_dados.head() #ver os primeiros registros
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 0  01/08/2020   08:37:48         2020    SP         70734
# 1  01/08/2020   08:37:48         2020    SP         70734
# 2  01/08/2020   08:37:48         2020    SP         70734
# 3  01/08/2020   08:37:48         2020    SP         70734
# 4  01/08/2020   08:37:48         2020    SP         70734
#
#            NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  NR_ZONA  \
# 0  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
# 1  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
# 2  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
# 3  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
# 4  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
#
#    CD_GENERO  ... CD_ESTADO_CIVIL  DS_ESTADO_CIVIL CD_FAIXA_ETARIA  \
# 0          4  ...               3           CASADO            7074
# ...

# %%
base_dados.columns #verificar colunas que tem
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'SG_UF', 'CD_MUNICIPIO',
#        'NM_MUNICIPIO', 'CD_MUN_SIT_BIOMETRIA', 'DS_MUN_SIT_BIOMETRIA',
#        'NR_ZONA', 'CD_GENERO', 'DS_GENERO', 'CD_ESTADO_CIVIL',
#        'DS_ESTADO_CIVIL', 'CD_FAIXA_ETARIA', 'DS_FAIXA_ETARIA',
#        'CD_GRAU_ESCOLARIDADE', 'DS_GRAU_ESCOLARIDADE', 'QT_ELEITORES_PERFIL',
#        'QT_ELEITORES_BIOMETRIA', 'QT_ELEITORES_DEFICIENCIA',
#        'QT_ELEITORES_INC_NM_SOCIAL'],
#       dtype='object')

# %%
#verificar quantos campos nulos tem
base_dados.isnull().sum()
# Out:
# DT_GERACAO                    0
# HH_GERACAO                    0
# ANO_ELEICAO                   0
# SG_UF                         0
# CD_MUNICIPIO                  0
# NM_MUNICIPIO                  0
# CD_MUN_SIT_BIOMETRIA          0
# DS_MUN_SIT_BIOMETRIA          0
# NR_ZONA                       0
# CD_GENERO                     0
# DS_GENERO                     0
# CD_ESTADO_CIVIL               0
# DS_ESTADO_CIVIL               0
# CD_FAIXA_ETARIA               0
# DS_FAIXA_ETARIA               0
# CD_GRAU_ESCOLARIDADE          0
# DS_GRAU_ESCOLARIDADE          0
# QT_ELEITORES_PERFIL           0
# QT_ELEITORES_BIOMETRIA        0
# QT_ELEITORES_DEFICIENCIA      0
# QT_ELEITORES_INC_NM_SOCIAL    0
# dtype: int64

# %%
#Retirar os valores nulos
base_dados.dropna(inplace = True) #inplace = True para aplicar diretamente nos dados e não precisar criar outra variavel

# %%
#verificar se ainda tem campos nulos
#valores nulos retirados com sucesso.
base_dados.isnull().sum()
# Out:
# DT_GERACAO                    0
# HH_GERACAO                    0
# ANO_ELEICAO                   0
# SG_UF                         0
# CD_MUNICIPIO                  0
# NM_MUNICIPIO                  0
# CD_MUN_SIT_BIOMETRIA          0
# DS_MUN_SIT_BIOMETRIA          0
# NR_ZONA                       0
# CD_GENERO                     0
# DS_GENERO                     0
# CD_ESTADO_CIVIL               0
# DS_ESTADO_CIVIL               0
# CD_FAIXA_ETARIA               0
# DS_FAIXA_ETARIA               0
# CD_GRAU_ESCOLARIDADE          0
# DS_GRAU_ESCOLARIDADE          0
# QT_ELEITORES_PERFIL           0
# QT_ELEITORES_BIOMETRIA        0
# QT_ELEITORES_DEFICIENCIA      0
# QT_ELEITORES_INC_NM_SOCIAL    0
# dtype: int64

# %%
#valores unicos
base_dados.nunique()
# Out:
# DT_GERACAO                       1
# HH_GERACAO                       1
# ANO_ELEICAO                      1
# SG_UF                           26
# CD_MUNICIPIO                  5569
# NM_MUNICIPIO                  5296
# CD_MUN_SIT_BIOMETRIA             1
# DS_MUN_SIT_BIOMETRIA             1
# NR_ZONA                        421
# CD_GENERO                        3
# DS_GENERO                        3
# CD_ESTADO_CIVIL                  6
# DS_ESTADO_CIVIL                  6
# CD_FAIXA_ETARIA                 23
# DS_FAIXA_ETARIA                 23
# CD_GRAU_ESCOLARIDADE             9
# DS_GRAU_ESCOLARIDADE             9
# QT_ELEITORES_PERFIL           2953
# QT_ELEITORES_BIOMETRIA        2658
# QT_ELEITORES_DEFICIENCIA       173
# QT_ELEITORES_INC_NM_SOCIAL       8
# dtype: int64

# %%
#verificando se tem erros de escrita e caractes especiais desnecessarios nas colunas com descrições.

# Os estados são = 'SP', 'BA', 'MS', 'MG', 'PR', 'MA', 'GO', 'AL', 'MT', 'PB',
#'TO','PA', 'PE', 'PI', 'ES', 'CE', 'RJ', 'RS', 'SC', 'RO', 'RN', 'SE','RR', 'AC'
base_dados['SG_UF'].unique()

#Os tipos de generos são = 'FEMININO', 'NÃO INFORMADO', 'MASCULINO'
base_dados['DS_GENERO'].unique()

#Os tipos de dados de estado cívil são = 'CASADO', 'VIÚVO', 'SEPARADO JUDICIALMENTE', 'DIVORCIADO', 'NÃO INFORMADO', 'SOLTEIRO'
base_dados['DS_ESTADO_CIVIL'].unique()


base_dados['DS_FAIXA_ETARIA'].unique()

# Os tipos de grau de escolaridade são = ENSINO FUNDAMENTAL INCOMPLETO', 'ENSINO FUNDAMENTAL COMPLETO',
# 'ENSINO MÉDIO INCOMPLETO', 'ENSINO MÉDIO COMPLETO','SUPERIOR COMPLETO', 'ANALFABETO', 'LÊ E ESCREVE',
# 'SUPERIOR INCOMPLETO', 'NÃO INFORMADO'
base_dados['DS_GRAU_ESCOLARIDADE'].unique()
# Out:
# array(['ENSINO FUNDAMENTAL INCOMPLETO', 'ENSINO FUNDAMENTAL COMPLETO',
#        'ENSINO MÉDIO INCOMPLETO', 'ENSINO MÉDIO COMPLETO',
#        'SUPERIOR COMPLETO', 'ANALFABETO', 'LÊ E ESCREVE',
#        'SUPERIOR INCOMPLETO', 'NÃO INFORMADO'], dtype=object)

# %%
#ELEITORADO POR GRAU DE ESCOLARIDADE
base_dados_sp = base_dados.query('SG_UF == "SP"')
base_dados_sp['DS_GRAU_ESCOLARIDADE'].value_counts()
# Out:
# DS_GRAU_ESCOLARIDADE
# ENSINO FUNDAMENTAL INCOMPLETO    105105
# ENSINO MÉDIO COMPLETO             93328
# ENSINO FUNDAMENTAL COMPLETO       83955
# LÊ E ESCREVE                      77219
# SUPERIOR COMPLETO                 76723
# ENSINO MÉDIO INCOMPLETO           75604
# ANALFABETO                        68972
# SUPERIOR INCOMPLETO               58592
# NÃO INFORMADO                         4
# Name: count, dtype: int64

# %%
#ELEITORADO POR GENERO
base_dados_sp = base_dados.query('SG_UF == "SP"')
base_dados_sp['DS_GENERO'].value_counts()
# Out:
# DS_GENERO
# FEMININO         332266
# MASCULINO        302334
# NÃO INFORMADO      4902
# Name: count, dtype: int64

# %%
#Eleitorados por estado civil
base_dados_sp['DS_ESTADO_CIVIL'].value_counts()
# Out:
# DS_ESTADO_CIVIL
# SOLTEIRO                  181901
# CASADO                    172563
# DIVORCIADO                107375
# VIÚVO                      93741
# SEPARADO JUDICIALMENTE     76379
# NÃO INFORMADO               7543
# Name: count, dtype: int64

# %%
#Eleitorado por FAIXA ETÁRIA
base_dados_sp = base_dados.query('SG_UF == "SP"')
base_dados_sp['DS_FAIXA_ETARIA'].value_counts()
# Out:
# DS_FAIXA_ETARIA
# 55 a 59 anos                      51824
# 60 a 64 anos                      51538
# 50 a 54 anos                      49890
# 65 a 69 anos                      49739
# 45 a 49 anos                      46555
# 70 a 74 anos                      45659
# 40 a 44 anos                      43636
# 75 a 79 anos                      39896
# 35 a 39 anos                      39191
# 80 a 84 anos                      33812
# 30 a 34 anos                      33540
# 25 a 29 anos                      28122
# 85 a 89 anos                      26486
# 21 a 24 anos                      20954
# 90 a 94 anos                      20669
# 95 a 99 anos                      15128
# 20 anos                           11184
# 19 anos                            9940
# 18 anos                            7720
# 100 anos ou mais                   6136
# 17 anos                            5185
# 16 anos                            2430
# Inválido                            268
# ...

# %%
#Eleitorados por Estado
base_dados[['SG_UF']].value_counts()
# Out:
# SG_UF
# SP       639502
# MG       609026
# RS       320563
# BA       317883
# PR       287673
# SC       198579
# RJ       197273
# GO       171810
# CE       160160
# PE       159852
# MA       141477
# PB       140778
# PI       128306
# PA       120859
# RN       105078
# MT        93626
# TO        73793
# AL        69281
# ES        68774
# MS        66692
# SE        50469
# AM        50225
# RO        39554
# AC        15844
# AP        10942
# RR        10488
# Name: count, dtype: int64

# %%
#mais eleitores no estado de são paulo
base_dados_sp['NM_MUNICIPIO'].value_counts()
# Out:
# NM_MUNICIPIO
# SÃO PAULO                66836
# CAMPINAS                  8202
# GUARULHOS                 6829
# SANTO ANDRÉ               6542
# SÃO BERNARDO DO CAMPO     6434
#                          ...
# VITÓRIA BRASIL             378
# SÃO JOÃO DE IRACEMA        376
# PRACINHA                   358
# NOVA CASTILHO              321
# BORÁ                       321
# Name: count, Length: 645, dtype: int64

# %% [markdown]
# ANALISE TABELA RESULTADO:

# %%
# Retirar colunas q não serão utilizadas
# Serão retiradas as colunas com apenas 1 informação
# DATA GERAÇÃO = 01/08/2020
# HH_GERACAO = 08:37:48
# ANO_ELEICAO = 1
# CD_MUN_SIT_BIOMETRIA = 0
# DS_MUN_SIT_BIOMETRIA = Sem biometria

#tabela final com colunas que não foram utilizadas removidas.
base_dados.drop(["DT_GERACAO", "HH_GERACAO", "ANO_ELEICAO","CD_MUN_SIT_BIOMETRIA","DS_MUN_SIT_BIOMETRIA"], axis = 1)
# Out:
#         SG_UF  CD_MUNICIPIO          NM_MUNICIPIO  NR_ZONA  CD_GENERO  \
# 0          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# 1          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# 2          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# 3          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# 4          SP         70734  SÃO BENTO DO SAPUCAÍ      314          4
# ...       ...           ...                   ...      ...        ...
# 4248502    PR         74349  FLOR DA SERRA DO SUL      140          4
# 4248503    PR         74349  FLOR DA SERRA DO SUL      140          4
# 4248504    PR         74349  FLOR DA SERRA DO SUL      140          4
# 4248505    PR         74349  FLOR DA SERRA DO SUL      140          4
# 4248506    PR         74349  FLOR DA SERRA DO SUL      140          4
#
#         DS_GENERO  CD_ESTADO_CIVIL DS_ESTADO_CIVIL  CD_FAIXA_ETARIA  \
# ...

# %%
#indicar o caminho do arquivo(onde o arquivo está localizado na maquina)
path2 = r"D:\resultados\SP_turno_1.csv"

# %%
base_dados2 = pd.read_csv(path2, sep=';',encoding='latin-1')
base_dados2
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO  \
# 0        18/11/2020   15:49:53         2020                0
# 1        18/11/2020   15:49:53         2020                0
# 2        18/11/2020   15:49:53         2020                0
# 3        18/11/2020   15:49:53         2020                0
# 4        18/11/2020   15:49:53         2020                0
# ...             ...        ...          ...              ...
# 9433995  18/11/2020   15:49:53         2020                0
# 9433996  18/11/2020   15:49:53         2020                0
# 9433997  18/11/2020   15:49:53         2020                0
# 9433998  18/11/2020   15:49:53         2020                0
# 9433999  18/11/2020   15:49:53         2020                0
#
#            NM_TIPO_ELEICAO  CD_PLEITO   DT_PLEITO  NR_TURNO  CD_ELEICAO  \
# 0        Eleição Ordinária        304  15/11/2020         1         426
# 1        Eleição Ordinária        304  15/11/2020         1         426
# ...

# %%
base_dados2.columns
# Out:
# Index(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'CD_TIPO_ELEICAO',
#        'NM_TIPO_ELEICAO', 'CD_PLEITO', 'DT_PLEITO', 'NR_TURNO', 'CD_ELEICAO',
#        'DS_ELEICAO', 'SG_UF', 'CD_MUNICIPIO', 'NM_MUNICIPIO', 'NR_ZONA',
#        'NR_SECAO', 'NR_LOCAL_VOTACAO', 'CD_CARGO_PERGUNTA',
#        'DS_CARGO_PERGUNTA', 'NR_PARTIDO', 'SG_PARTIDO', 'NM_PARTIDO',
#        'DT_BU_RECEBIDO', 'QT_APTOS', 'QT_COMPARECIMENTO', 'QT_ABSTENCOES',
#        'CD_TIPO_URNA', 'DS_TIPO_URNA', 'CD_TIPO_VOTAVEL', 'DS_TIPO_VOTAVEL',
#        'NR_VOTAVEL', 'NM_VOTAVEL', 'QT_VOTOS', 'NR_URNA_EFETIVADA',
#        'CD_CARGA_1_URNA_EFETIVADA', 'CD_CARGA_2_URNA_EFETIVADA',
#        'CD_FLASHCARD_URNA_EFETIVADA', 'DT_CARGA_URNA_EFETIVADA',
#        'DS_CARGO_PERGUNTA_SECAO', 'DS_AGREGADAS', 'DT_ABERTURA',
#        'DT_ENCERRAMENTO', 'QT_ELEITORES_BIOMETRIA_NH', 'DT_EMISSAO_BU',
#        'NR_JUNTA_APURADORA', 'NR_TURMA_APURADORA'],
#       dtype='object')

# %%
#verificar quantos campos nulos tem
base_dados2.isnull().sum()
# Out:
# DT_GERACAO                       0
# HH_GERACAO                       0
# ANO_ELEICAO                      0
# CD_TIPO_ELEICAO                  0
# NM_TIPO_ELEICAO                  0
# CD_PLEITO                        0
# DT_PLEITO                        0
# NR_TURNO                         0
# CD_ELEICAO                       0
# DS_ELEICAO                       0
# SG_UF                            0
# CD_MUNICIPIO                     0
# NM_MUNICIPIO                     0
# NR_ZONA                          0
# NR_SECAO                         0
# NR_LOCAL_VOTACAO                 0
# CD_CARGO_PERGUNTA                0
# DS_CARGO_PERGUNTA                0
# NR_PARTIDO                       0
# SG_PARTIDO                       0
# NM_PARTIDO                       0
# DT_BU_RECEBIDO                   0
# QT_APTOS                         0
# QT_COMPARECIMENTO                0
# QT_ABSTENCOES                    0
# CD_TIPO_URNA                     0
# DS_TIPO_URNA                     0
# ...

# %%
#verificando as informações das colunas com valores nulos

#data abertura e data fechamento aproximadamente o mesmo valor não sendo necessario retirar 
#os campos nulos e não afeta a legetimidade dos votos.

#retirando valores nulos dos nomes dos votaveis(por não saber se estes votos não foram feitos irregularmente)
base_dados2["NM_VOTAVEL"]
#base_dados2["DT_ABERTURA"]
#base_dados2["DT_ENCERRAMENTO"]
# Out:
# 0                    Branco
# 1              JILMAR TATTO
# 2              MARINA HELOU
# 3             MÁRCIO FRANÇA
# 4               BRUNO COVAS
#                  ...
# 9433995     DANIELE DO IVAN
# 9433996        NELSON VITAL
# 9433997        REPUBLICANOS
# 9433998                Nulo
# 9433999    EDIVALDO CAETANO
# Name: NM_VOTAVEL, Length: 9434000, dtype: object

# %%
#substituir valor nulo de datas por data especifica pois a data de abertura e fechamento a principio não implica em fraude
base_dados2["DT_ABERTURA"].fillna("15/11/2020 07:00:00", inplace=True)
base_dados2["DT_ENCERRAMENTO"].fillna("15/11/2020 17:02:46", inplace=True)#substitui o nulo pelo valor do primeiro dado

# %%
#retirando valor nulo dE NM_VOTAVEL
base_dados2.dropna(inplace = True)

# %%
#verificar se os campos nulos foram retirados
base_dados2.isnull().sum()
# Out:
# DT_GERACAO                     0
# HH_GERACAO                     0
# ANO_ELEICAO                    0
# CD_TIPO_ELEICAO                0
# NM_TIPO_ELEICAO                0
# CD_PLEITO                      0
# DT_PLEITO                      0
# NR_TURNO                       0
# CD_ELEICAO                     0
# DS_ELEICAO                     0
# SG_UF                          0
# CD_MUNICIPIO                   0
# NM_MUNICIPIO                   0
# NR_ZONA                        0
# NR_SECAO                       0
# NR_LOCAL_VOTACAO               0
# CD_CARGO_PERGUNTA              0
# DS_CARGO_PERGUNTA              0
# NR_PARTIDO                     0
# SG_PARTIDO                     0
# NM_PARTIDO                     0
# DT_BU_RECEBIDO                 0
# QT_APTOS                       0
# QT_COMPARECIMENTO              0
# QT_ABSTENCOES                  0
# CD_TIPO_URNA                   0
# DS_TIPO_URNA                   0
# CD_TIPO_VOTAVEL                0
# ...

# %%
base_dados2.nunique()
# Out:
# DT_GERACAO                         1
# HH_GERACAO                         1
# ANO_ELEICAO                        1
# CD_TIPO_ELEICAO                    1
# NM_TIPO_ELEICAO                    1
# CD_PLEITO                          1
# DT_PLEITO                          1
# NR_TURNO                           1
# CD_ELEICAO                         1
# DS_ELEICAO                         1
# SG_UF                              1
# CD_MUNICIPIO                     645
# NM_MUNICIPIO                     645
# NR_ZONA                          393
# NR_SECAO                        1017
# NR_LOCAL_VOTACAO                 166
# CD_CARGO_PERGUNTA                  2
# DS_CARGO_PERGUNTA                  2
# NR_PARTIDO                        34
# SG_PARTIDO                        34
# NM_PARTIDO                        34
# DT_BU_RECEBIDO                 13799
# QT_APTOS                         461
# QT_COMPARECIMENTO                399
# QT_ABSTENCOES                    250
# ...

# %%
#Na tabela de resultado a cidade de São paulo com o partido mais votado foi partido da social democracia brasileira = 241.312
#Na tabela de resultado a cidade de São paulo o partido menos votado foi partido da causa operária = 1425

base_dados_estado = base_dados2.query('NM_MUNICIPIO == "SÃO PAULO"')
base_dados_estado['NM_PARTIDO'].value_counts()
# Out:
# NM_PARTIDO
# Partido da Social Democracia Brasileira           241312
# Partido Socialismo e Liberdade                    240046
# Partido dos Trabalhadores                         229627
# Democratas                                        182103
# REPUBLICANOS                                      180760
# Podemos                                           148409
# Patriota                                          135433
# Partido Social Democrático                        125537
# Partido Socialista Brasileiro                     123533
# Partido Social Liberal                            121806
# Partido Novo                                       98244
# Movimento Democrático Brasileiro                   97563
# #NULO#                                             89563
# Partido Liberal                                    84739
# PROGRESSISTAS                                      68992
# Partido Comunista do Brasil                        58904
# ...

# %%
#Na tabela de resultado como todos os municipios
#partido mais votado Partido da Social Democracia Brasileira com  820.491 votos
#partido menos votado Partido da Causa Operária com 2.584 votos

base_dados2['NM_PARTIDO'].value_counts()
# Out:
# NM_PARTIDO
# Partido da Social Democracia Brasileira           820491
# Democratas                                        583758
# REPUBLICANOS                                      571537
# Partido Social Democrático                        557710
# Partido dos Trabalhadores                         555238
# Podemos                                           500386
# Movimento Democrático Brasileiro                  487924
# Partido Liberal                                   486507
# Partido Social Liberal                            401934
# Partido Socialismo e Liberdade                    386545
# Partido Socialista Brasileiro                     381075
# PROGRESSISTAS                                     363607
# Partido Trabalhista Brasileiro                    360492
# #NULO#                                            342562
# Patriota                                          337236
# Partido Democrático Trabalhista                   283159
# ...

# %%
#A ZONA QUE MAIS VOTOU NO PARTIDO MAIS VOTADO FOI A ZONA 376 COM 7.632 VOTOS
#A ZONA QUE MENOS VOTOU FOI A 36 COM 26 VOTOS
base_dados_zona = base_dados2.query('NM_PARTIDO == "Partido da Social Democracia Brasileira"')
base_dados_zona['NR_ZONA'].value_counts()
# Out:
# NR_ZONA
# 376    7632
# 174    7317
# 406    6968
# 374    6961
# 253    6704
#        ...
# 50       81
# 318      73
# 71       57
# 96       56
# 36       26
# Name: count, Length: 386, dtype: int64

# %%
#QUANTIDADE DE URNA APURADA NA CIDADE DE SP  =  2.736.857

base_dados_consulta = base_dados2.query('NM_MUNICIPIO == "SÃO PAULO" ')
base_dados_consulta['DS_TIPO_URNA'].value_counts()
# Out:
# DS_TIPO_URNA
# APURADA    2736857
# Name: count, dtype: int64

# %%
base_dados2.drop(["DT_GERACAO", "HH_GERACAO", "ANO_ELEICAO","CD_TIPO_ELEICAO","NM_TIPO_ELEICAO","NM_TIPO_ELEICAO","CD_PLEITO","DT_PLEITO"], axis = 1)
# Out:
#          NR_TURNO  CD_ELEICAO                DS_ELEICAO SG_UF  CD_MUNICIPIO  \
# 0               1         426  Eleições Municipais 2020    SP         71072
# 1               1         426  Eleições Municipais 2020    SP         71072
# 2               1         426  Eleições Municipais 2020    SP         71072
# 3               1         426  Eleições Municipais 2020    SP         71072
# 4               1         426  Eleições Municipais 2020    SP         71072
# ...           ...         ...                       ...   ...           ...
# 9433995         1         426  Eleições Municipais 2020    SP         70157
# 9433996         1         426  Eleições Municipais 2020    SP         70157
# 9433997         1         426  Eleições Municipais 2020    SP         70157
# 9433998         1         426  Eleições Municipais 2020    SP         70157
# 9433999         1         426  Eleições Municipais 2020    SP         70157
#
# ...
